# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

from sklearn.model_selection import train_test_split

import sklearn.neighbors
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# **First Step:** I need to **upload** my csv file

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dea94c84-151c-4cdf-bc13-0f25d80c1b67" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dea94c84-151c-4cdf-bc13-0f25d80c1b67">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df = pd.read_csv ( io.BytesIO(uploaded['Cancer_Diagnostic.csv']),sep=";")

# %% [markdown]
# **2nd step:** **check** that my data has been successfully uploaded

# %%
df.head()
# Out:
#          id diagnosis  "radius_mean"  "texture_mean"  "perimeter_mean"  \
# 0    842302         M          17.99           10.38            122.80
# 1    842517         M          20.57           17.77            132.90
# 2  84300903         M          19.69           21.25            130.00
# 3  84348301         M          11.42           20.38             77.58
# 4  84358402         M          20.29           14.34            135.10
#
#    "area_mean"  "smoothness_mean"  "compactness_mean"  "concavity_mean"  \
# 0       1001.0            0.11840             0.27760            0.3001
# 1       1326.0            0.08474             0.07864            0.0869
# 2       1203.0            0.10960             0.15990            0.1974
# 3        386.1            0.14250             0.28390            0.2414
# 4       1297.0            0.10030             0.13280            0.1980
#
#    "concave points_mean"  ...  "radius_worst"  "texture_worst"  \
# ...

# %% [markdown]
# **Next:** Get full **description** about my data

# %%
df.describe()
# Out:
#                  id  "radius_mean"  "texture_mean"  "perimeter_mean"  \
# count  5.690000e+02     569.000000      569.000000        569.000000
# mean   3.037183e+07      14.127292       19.289649         91.969033
# std    1.250206e+08       3.524049        4.301036         24.298981
# min    8.670000e+03       6.981000        9.710000         43.790000
# 25%    8.692180e+05      11.700000       16.170000         75.170000
# 50%    9.060240e+05      13.370000       18.840000         86.240000
# 75%    8.813129e+06      15.780000       21.800000        104.100000
# max    9.113205e+08      28.110000       39.280000        188.500000
#
#        "area_mean"  "smoothness_mean"  "compactness_mean"  "concavity_mean"  \
# count   569.000000         569.000000          569.000000        569.000000
# mean    654.889104           0.096360            0.104341          0.088799
# std     351.914129           0.014064            0.052813          0.079720
# ...

# %%
df.shape
# Out:
# (569, 32)

# %% [markdown]
# **Now**, I need to check whether there is any **missed values **in my data => I have no missing value

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# **Next, **I need to check if there is **imabalanced data** based on the outcome (underrepresented class) => the frequencies for the different types are close so my data is balance

# %%
df["diagnosis"].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
sns.countplot(x="diagnosis", data=df)
# Out:
# <AxesSubplot:xlabel='diagnosis', ylabel='count'>

# %% [markdown]
# Next, Check for if there is correlation between predictor variables => we can see that most of them are not very correlated

# %%
df.corr()
# Out:
#                                  id  "radius_mean"  "texture_mean"  \
# id                         1.000000       0.074626        0.099770
# "radius_mean"              0.074626       1.000000        0.323782
# "texture_mean"             0.099770       0.323782        1.000000
# "perimeter_mean"           0.073159       0.997855        0.329533
# "area_mean"                0.096893       0.987357        0.321086
# "smoothness_mean"         -0.012968       0.170581       -0.023389
# "compactness_mean"         0.000096       0.506124        0.236702
# "concavity_mean"           0.050080       0.676764        0.302418
# "concave points_mean"      0.044158       0.822529        0.293464
# "symmetry_mean"           -0.022114       0.147741        0.071401
# "fractal_dimension_mean"  -0.052511      -0.311631       -0.076437
# "radius_se"                0.143048       0.679090        0.275869
# "texture_se"              -0.007526      -0.097317        0.386358
# ...

# %% [markdown]
# Now, I need to split my data into **training and test set** => y is the target variable

# %%
x = df.iloc[:, 2:]
y = df.iloc[:, 1]
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = 0, test_size = 0.35)

# %% [markdown]
# Next, we need to **standarize** the data

# %%
sc_x = StandardScaler()
x_train = sc_x.fit_transform(x_train)
x_test = sc_x.transform(x_test)

# %%
import math
math.sqrt(len(y_test))
# Out:
# 14.142135623730951

# %% [markdown]
# Eventually, we generate the **classification process** and make the prediction (y_pred)

# %%
classifier = KNeighborsClassifier(n_neighbors = 9, p = 2, metric = 'euclidean')
classifier.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=9)

# %%
y_pred = classifier.predict(x_test)
y_pred
# Out:
# array(['M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'M', 'B', 'M', 'M', 'M', 'M', 'M', 'B', 'B', 'M', 'B',
#        'B', 'M', 'B', 'M', 'B', 'M', 'B', 'M', 'B', 'M', 'B', 'M', 'B',
#        'M', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'M', 'M',
#        'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'M',
#        'B', 'M', 'M', 'M', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B', 'B',
#        'B', 'B', 'M', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'M', 'B',
#        'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'B',
#        'M', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'M',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M',
#        'B', 'M', 'B', 'M', 'M', 'B', 'B', 'M', 'B', 'M', 'M', 'M', 'B',
# ...

# %% [markdown]
# **Finally,** check the accuracy of our prediction: we can observe that from our test set (200 observation: 35% of the dataset)=> for class 'B' we have: 126 observations out of 127 were predicted right, and for class 'M': 65 observations out of 73 were predicted correctly => the accuracy was (95.5%)

# %%
cm = confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[126   1]
#  [  8  65]]

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.955
